# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1288187380" href="javascript:toggle_input_1288187380()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1288187380;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1288187380 = document.getElementById("1288187380");
#                 var cell = link_1288187380;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1288187380;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1288187380 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1288187380 = cell.previousElementSibling;
#                 }
#                 input_1288187380.style.display = "none"; // hide
#
#                 toggle_input_1288187380 = function() {
#                     if (input_1288187380.style.display == "none") {
#                         input_1288187380.style.display = ""; // show
#                         link_1288187380.innerHTML = "Hide Input";
#                     } else {
#                         input_1288187380.style.display = "none"; // hide
#                         link_1288187380.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1288187380 = $("a[id='1288187380']");
#                 var cell_1288187380 = link_1288187380.parents("div.cell:first");
#                 if (cell_1288187380.length == 0) {
#                     cell_1288187380 = link_1288187380.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1288187380 = cell_1288187380.children("div.input");
#                 if (input_1288187380.length == 0) {
#                     input_1288187380 = cell_1288187380.prev("div.nbinput");
#                 }
#                 input_1288187380.hide();
#
#                 toggle_input_1288187380 = function() {
#                     if (input_1288187380.is(':hidden')) {
#                         input_1288187380.slideDown();
#                         link_1288187380[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1288187380.slideUp();
#                         link_1288187380[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1664541058" href="javascript:toggle_input_1664541058()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1664541058;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1664541058 = document.getElementById("1664541058");
#                 var cell = link_1664541058;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1664541058;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1664541058 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1664541058 = cell.previousElementSibling;
#                 }
#                 input_1664541058.style.display = "none"; // hide
#
#                 toggle_input_1664541058 = function() {
#                     if (input_1664541058.style.display == "none") {
#                         input_1664541058.style.display = ""; // show
#                         link_1664541058.innerHTML = "Hide Input";
#                     } else {
#                         input_1664541058.style.display = "none"; // hide
#                         link_1664541058.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1664541058 = $("a[id='1664541058']");
#                 var cell_1664541058 = link_1664541058.parents("div.cell:first");
#                 if (cell_1664541058.length == 0) {
#                     cell_1664541058 = link_1664541058.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1664541058 = cell_1664541058.children("div.input");
#                 if (input_1664541058.length == 0) {
#                     input_1664541058 = cell_1664541058.prev("div.nbinput");
#                 }
#                 input_1664541058.hide();
#
#                 toggle_input_1664541058 = function() {
#                     if (input_1664541058.is(':hidden')) {
#                         input_1664541058.slideDown();
#                         link_1664541058[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1664541058.slideUp();
#                         link_1664541058[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="673782737" href="javascript:toggle_input_673782737()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_673782737;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_673782737 = document.getElementById("673782737");
#                 var cell = link_673782737;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_673782737;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_673782737 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_673782737 = cell.previousElementSibling;
#                 }
#                 input_673782737.style.display = "none"; // hide
#
#                 toggle_input_673782737 = function() {
#                     if (input_673782737.style.display == "none") {
#                         input_673782737.style.display = ""; // show
#                         link_673782737.innerHTML = "Hide Input";
#                     } else {
#                         input_673782737.style.display = "none"; // hide
#                         link_673782737.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_673782737 = $("a[id='673782737']");
#                 var cell_673782737 = link_673782737.parents("div.cell:first");
#                 if (cell_673782737.length == 0) {
#                     cell_673782737 = link_673782737.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_673782737 = cell_673782737.children("div.input");
#                 if (input_673782737.length == 0) {
#                     input_673782737 = cell_673782737.prev("div.nbinput");
#                 }
#                 input_673782737.hide();
#
#                 toggle_input_673782737 = function() {
#                     if (input_673782737.is(':hidden')) {
#                         input_673782737.slideDown();
#                         link_673782737[0].innerHTML = "Hide Input";
#                     } else {
#                         input_673782737.slideUp();
#                         link_673782737[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="810442018" href="javascript:toggle_input_810442018()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_810442018;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_810442018 = document.getElementById("810442018");
#                 var cell = link_810442018;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_810442018;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_810442018 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_810442018 = cell.previousElementSibling;
#                 }
#                 input_810442018.style.display = "none"; // hide
#
#                 toggle_input_810442018 = function() {
#                     if (input_810442018.style.display == "none") {
#                         input_810442018.style.display = ""; // show
#                         link_810442018.innerHTML = "Hide Input";
#                     } else {
#                         input_810442018.style.display = "none"; // hide
#                         link_810442018.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_810442018 = $("a[id='810442018']");
#                 var cell_810442018 = link_810442018.parents("div.cell:first");
#                 if (cell_810442018.length == 0) {
#                     cell_810442018 = link_810442018.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_810442018 = cell_810442018.children("div.input");
#                 if (input_810442018.length == 0) {
#                     input_810442018 = cell_810442018.prev("div.nbinput");
#                 }
#                 input_810442018.hide();
#
#                 toggle_input_810442018 = function() {
#                     if (input_810442018.is(':hidden')) {
#                         input_810442018.slideDown();
#                         link_810442018[0].innerHTML = "Hide Input";
#                     } else {
#                         input_810442018.slideUp();
#                         link_810442018[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="590903159" href="javascript:toggle_input_590903159()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_590903159;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_590903159 = document.getElementById("590903159");
#                 var cell = link_590903159;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_590903159;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_590903159 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_590903159 = cell.previousElementSibling;
#                 }
#                 input_590903159.style.display = "none"; // hide
#
#                 toggle_input_590903159 = function() {
#                     if (input_590903159.style.display == "none") {
#                         input_590903159.style.display = ""; // show
#                         link_590903159.innerHTML = "Hide Input";
#                     } else {
#                         input_590903159.style.display = "none"; // hide
#                         link_590903159.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_590903159 = $("a[id='590903159']");
#                 var cell_590903159 = link_590903159.parents("div.cell:first");
#                 if (cell_590903159.length == 0) {
#                     cell_590903159 = link_590903159.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_590903159 = cell_590903159.children("div.input");
#                 if (input_590903159.length == 0) {
#                     input_590903159 = cell_590903159.prev("div.nbinput");
#                 }
#                 input_590903159.hide();
#
#                 toggle_input_590903159 = function() {
#                     if (input_590903159.is(':hidden')) {
#                         input_590903159.slideDown();
#                         link_590903159[0].innerHTML = "Hide Input";
#                     } else {
#                         input_590903159.slideUp();
#                         link_590903159[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="365821777" href="javascript:toggle_input_365821777()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_365821777;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_365821777 = document.getElementById("365821777");
#                 var cell = link_365821777;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_365821777;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_365821777 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_365821777 = cell.previousElementSibling;
#                 }
#                 input_365821777.style.display = "none"; // hide
#
#                 toggle_input_365821777 = function() {
#                     if (input_365821777.style.display == "none") {
#                         input_365821777.style.display = ""; // show
#                         link_365821777.innerHTML = "Hide Input";
#                     } else {
#                         input_365821777.style.display = "none"; // hide
#                         link_365821777.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_365821777 = $("a[id='365821777']");
#                 var cell_365821777 = link_365821777.parents("div.cell:first");
#                 if (cell_365821777.length == 0) {
#                     cell_365821777 = link_365821777.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_365821777 = cell_365821777.children("div.input");
#                 if (input_365821777.length == 0) {
#                     input_365821777 = cell_365821777.prev("div.nbinput");
#                 }
#                 input_365821777.hide();
#
#                 toggle_input_365821777 = function() {
#                     if (input_365821777.is(':hidden')) {
#                         input_365821777.slideDown();
#                         link_365821777[0].innerHTML = "Hide Input";
#                     } else {
#                         input_365821777.slideUp();
#                         link_365821777[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1797635524" href="javascript:toggle_input_1797635524()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1797635524;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1797635524 = document.getElementById("1797635524");
#                 var cell = link_1797635524;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1797635524;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1797635524 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1797635524 = cell.previousElementSibling;
#                 }
#                 input_1797635524.style.display = "none"; // hide
#
#                 toggle_input_1797635524 = function() {
#                     if (input_1797635524.style.display == "none") {
#                         input_1797635524.style.display = ""; // show
#                         link_1797635524.innerHTML = "Hide Input";
#                     } else {
#                         input_1797635524.style.display = "none"; // hide
#                         link_1797635524.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1797635524 = $("a[id='1797635524']");
#                 var cell_1797635524 = link_1797635524.parents("div.cell:first");
#                 if (cell_1797635524.length == 0) {
#                     cell_1797635524 = link_1797635524.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1797635524 = cell_1797635524.children("div.input");
#                 if (input_1797635524.length == 0) {
#                     input_1797635524 = cell_1797635524.prev("div.nbinput");
#                 }
#                 input_1797635524.hide();
#
#                 toggle_input_1797635524 = function() {
#                     if (input_1797635524.is(':hidden')) {
#                         input_1797635524.slideDown();
#                         link_1797635524[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1797635524.slideUp();
#                         link_1797635524[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1866264704" href="javascript:toggle_input_1866264704()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1866264704;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1866264704 = document.getElementById("1866264704");
#                 var cell = link_1866264704;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1866264704;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1866264704 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1866264704 = cell.previousElementSibling;
#                 }
#                 input_1866264704.style.display = "none"; // hide
#
#                 toggle_input_1866264704 = function() {
#                     if (input_1866264704.style.display == "none") {
#                         input_1866264704.style.display = ""; // show
#                         link_1866264704.innerHTML = "Hide Input";
#                     } else {
#                         input_1866264704.style.display = "none"; // hide
#                         link_1866264704.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1866264704 = $("a[id='1866264704']");
#                 var cell_1866264704 = link_1866264704.parents("div.cell:first");
#                 if (cell_1866264704.length == 0) {
#                     cell_1866264704 = link_1866264704.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1866264704 = cell_1866264704.children("div.input");
#                 if (input_1866264704.length == 0) {
#                     input_1866264704 = cell_1866264704.prev("div.nbinput");
#                 }
#                 input_1866264704.hide();
#
#                 toggle_input_1866264704 = function() {
#                     if (input_1866264704.is(':hidden')) {
#                         input_1866264704.slideDown();
#                         link_1866264704[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1866264704.slideUp();
#                         link_1866264704[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="675349000" href="javascript:toggle_input_675349000()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_675349000;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_675349000 = document.getElementById("675349000");
#                 var cell = link_675349000;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_675349000;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_675349000 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_675349000 = cell.previousElementSibling;
#                 }
#                 input_675349000.style.display = "none"; // hide
#
#                 toggle_input_675349000 = function() {
#                     if (input_675349000.style.display == "none") {
#                         input_675349000.style.display = ""; // show
#                         link_675349000.innerHTML = "Hide Input";
#                     } else {
#                         input_675349000.style.display = "none"; // hide
#                         link_675349000.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_675349000 = $("a[id='675349000']");
#                 var cell_675349000 = link_675349000.parents("div.cell:first");
#                 if (cell_675349000.length == 0) {
#                     cell_675349000 = link_675349000.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_675349000 = cell_675349000.children("div.input");
#                 if (input_675349000.length == 0) {
#                     input_675349000 = cell_675349000.prev("div.nbinput");
#                 }
#                 input_675349000.hide();
#
#                 toggle_input_675349000 = function() {
#                     if (input_675349000.is(':hidden')) {
#                         input_675349000.slideDown();
#                         link_675349000[0].innerHTML = "Hide Input";
#                     } else {
#                         input_675349000.slideUp();
#                         link_675349000[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="88829804" href="javascript:toggle_input_88829804()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_88829804;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_88829804 = document.getElementById("88829804");
#                 var cell = link_88829804;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_88829804;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_88829804 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_88829804 = cell.previousElementSibling;
#                 }
#                 input_88829804.style.display = "none"; // hide
#
#                 toggle_input_88829804 = function() {
#                     if (input_88829804.style.display == "none") {
#                         input_88829804.style.display = ""; // show
#                         link_88829804.innerHTML = "Hide Input";
#                     } else {
#                         input_88829804.style.display = "none"; // hide
#                         link_88829804.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_88829804 = $("a[id='88829804']");
#                 var cell_88829804 = link_88829804.parents("div.cell:first");
#                 if (cell_88829804.length == 0) {
#                     cell_88829804 = link_88829804.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_88829804 = cell_88829804.children("div.input");
#                 if (input_88829804.length == 0) {
#                     input_88829804 = cell_88829804.prev("div.nbinput");
#                 }
#                 input_88829804.hide();
#
#                 toggle_input_88829804 = function() {
#                     if (input_88829804.is(':hidden')) {
#                         input_88829804.slideDown();
#                         link_88829804[0].innerHTML = "Hide Input";
#                     } else {
#                         input_88829804.slideUp();
#                         link_88829804[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="170374702" href="javascript:toggle_input_170374702()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_170374702;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_170374702 = document.getElementById("170374702");
#                 var cell = link_170374702;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_170374702;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_170374702 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_170374702 = cell.previousElementSibling;
#                 }
#                 input_170374702.style.display = "none"; // hide
#
#                 toggle_input_170374702 = function() {
#                     if (input_170374702.style.display == "none") {
#                         input_170374702.style.display = ""; // show
#                         link_170374702.innerHTML = "Hide Input";
#                     } else {
#                         input_170374702.style.display = "none"; // hide
#                         link_170374702.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_170374702 = $("a[id='170374702']");
#                 var cell_170374702 = link_170374702.parents("div.cell:first");
#                 if (cell_170374702.length == 0) {
#                     cell_170374702 = link_170374702.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_170374702 = cell_170374702.children("div.input");
#                 if (input_170374702.length == 0) {
#                     input_170374702 = cell_170374702.prev("div.nbinput");
#                 }
#                 input_170374702.hide();
#
#                 toggle_input_170374702 = function() {
#                     if (input_170374702.is(':hidden')) {
#                         input_170374702.slideDown();
#                         link_170374702[0].innerHTML = "Hide Input";
#                     } else {
#                         input_170374702.slideUp();
#                         link_170374702[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1141791926" href="javascript:toggle_input_1141791926()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1141791926;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1141791926 = document.getElementById("1141791926");
#                 var cell = link_1141791926;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1141791926;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1141791926 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1141791926 = cell.previousElementSibling;
#                 }
#                 input_1141791926.style.display = "none"; // hide
#
#                 toggle_input_1141791926 = function() {
#                     if (input_1141791926.style.display == "none") {
#                         input_1141791926.style.display = ""; // show
#                         link_1141791926.innerHTML = "Hide Input";
#                     } else {
#                         input_1141791926.style.display = "none"; // hide
#                         link_1141791926.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1141791926 = $("a[id='1141791926']");
#                 var cell_1141791926 = link_1141791926.parents("div.cell:first");
#                 if (cell_1141791926.length == 0) {
#                     cell_1141791926 = link_1141791926.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1141791926 = cell_1141791926.children("div.input");
#                 if (input_1141791926.length == 0) {
#                     input_1141791926 = cell_1141791926.prev("div.nbinput");
#                 }
#                 input_1141791926.hide();
#
#                 toggle_input_1141791926 = function() {
#                     if (input_1141791926.is(':hidden')) {
#                         input_1141791926.slideDown();
#                         link_1141791926[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1141791926.slideUp();
#                         link_1141791926[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="1904635552" href="javascript:toggle_input_1904635552()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1904635552;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1904635552 = document.getElementById("1904635552");
#                 var cell = link_1904635552;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1904635552;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1904635552 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1904635552 = cell.previousElementSibling;
#                 }
#                 input_1904635552.style.display = "none"; // hide
#
#                 toggle_input_1904635552 = function() {
#                     if (input_1904635552.style.display == "none") {
#                         input_1904635552.style.display = ""; // show
#                         link_1904635552.innerHTML = "Hide Input";
#                     } else {
#                         input_1904635552.style.display = "none"; // hide
#                         link_1904635552.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1904635552 = $("a[id='1904635552']");
#                 var cell_1904635552 = link_1904635552.parents("div.cell:first");
#                 if (cell_1904635552.length == 0) {
#                     cell_1904635552 = link_1904635552.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1904635552 = cell_1904635552.children("div.input");
#                 if (input_1904635552.length == 0) {
#                     input_1904635552 = cell_1904635552.prev("div.nbinput");
#                 }
#                 input_1904635552.hide();
#
#                 toggle_input_1904635552 = function() {
#                     if (input_1904635552.is(':hidden')) {
#                         input_1904635552.slideDown();
#                         link_1904635552[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1904635552.slideUp();
#                         link_1904635552[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
